# %% [markdown]
# # Introduction Task 2 Day_1

# %%
print(3+2)
# Out:
# 5

# %%
print(5-2)
# Out:
# 3

# %%
print(10/2)
# Out:
# 5.0

# %%
print(10//2)
# Out:
# 5

# %%
print(2**3)
# Out:
# 8

# %%
print(10%3)
# Out:
# 1

# %% [markdown]
# # Data Type Check Up

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(5.5))
# Out:
# <class 'float'>

# %%
print(type("Abhijeeth"))
# Out:
# <class 'str'>

# %%
print(type(2+8j))
# Out:
# <class 'complex'>

# %%
print(type([1,2,3,4,5]))
# Out:
# <class 'list'>

# %%
print(type({"name" : "Senapati sir"}))
# Out:
# <class 'dict'>

# %%
print(type({1,2,3,4,5}))
# Out:
# <class 'set'>

# %%
print(type(("Apple" ,"Banana", "Peanuts")))
# Out:
# <class 'tuple'>

# %%
print(type(3==3))
# Out:
# <class 'bool'>

# %%
print(type(3 >= 3))
# Out:
# <class 'bool'>

# %% [markdown]
# # Arithmrtic operator

# %%
print("Addition :" ,3+2)
# Out:
# Addition : 5

# %%
print("Subtraction : ", 3-5)
# Out:
# Subtraction :  -2

# %%
print("Multiplication :", 2*3)
# Out:
# Multiplication : 6

# %%
print("Division :", 6/2) # with decimal 
print("Division :", 6/3)
print("Division :", 6//2) # without decimal
print("Modulas :", 7%2) # only remainder
# Out:
# Division : 3.0
# Division : 2.0
# Division : 3
# Modulas : 1

# %%
print("Exponential :", 3**5)
# Out:
# Exponential : 243

# %%
print("Floating Point","PI", 3.14)
# Out:
# Floating Point PI 3.14

# %%
print("Floating point","Gravity_Number",9.8)
# Out:
# Floating point Gravity_Number 9.8

# %%
# complex number
print("Complex Number :", 1 + 1j) 
print("Multiply_complex_Number :",(1 + 1j)*(1 - 1j))
# Out:
# Complex Number : (1+1j)
# Multiply_complex_Number : (2+0j)

# %%
a = 3
b = 2
print(a)
print(b)
# Out:
# 3
# 2

# %%
total = a+b
total
# Out:
# 5

# %%
difference = a-b
difference
# Out:
# 1

# %%
prod = a*b
prod
# Out:
# 6

# %%
division = a/b
division
# Out:
# 1.5

# %%
remainder = a%b
remainder
# Out:
# 1

# %%
floor_Division = a//b
floor_Division
# Out:
# 1

# %%
expo =a**b
expo
# Out:
# 9

# %%
print(total)
print("a+b",total)
print("a-b",difference)
print("a*b",prod)
print("a/b",division)
print("a%b",remainder)
print("a//b",floor_Division)
print("a**b",expo)
# Out:
# 5
# a+b 5
# a-b 1
# a*b 6
# a/b 1.5
# a%b 1
# a//b 1
# a**b 9

# %%
num_One = 2
num_Two = 3

# %%
print(total,'=' ,num_One,'+',num_Two)
print(difference,'=' ,num_One,'-',num_Two)
print(prod,'=' ,num_One,'*',num_Two)
print(expo,'=' ,num_One,'**',num_Two)
print(division,'=' ,num_One,'/',num_Two)
print(floor_Division,'=' ,num_One,'//',num_Two)
# Out:
# 5 = 2 + 3
# 1 = 2 - 3
# 6 = 2 * 3
# 9 = 2 ** 3
# 1.5 = 2 / 3
# 1 = 2 // 3

# %%
# area of circle 
radius = 10
area_Circle = 2*3.14*radius
print("Area of circle :",area_Circle)
# Out:
# Area of circle : 62.800000000000004

# %%
length = 10
width = 20
area_reactangle = length * width
print("Area of Rectangle :",area_reactangle)
# Out:
# Area of Rectangle : 200

# %%
# weight of an object 
mass = 75
gravity = 981
weight = mass*gravity
print("weight: ", weight)
# Out:
# weight:  73575

# %%
print(3>=2)
print(3<=2)
print(3==2)
print(3!=2)
# Out:
# True
# False
# False
# True

# %%
print(len('mango') == len('avocado')) 
print(len('mango') != len('avocado')) 
print(len('mango') < len('avocado'))   
print(len('milk') != len('meat'))      
print(len('milk') == len('meat'))      
print(len('tomato') == len('potato'))  
print(len('python') > len('dragon'))
# Out:
# False
# True
# True
# False
# True
# True
# False

# %%
print('True == True: ', True == True)
print('True == False: ', True == False)
print('False == False:', False == False)
print('True and True: ', True and True)
print('True or False:', True or False)
# Out:
# True == True:  True
# True == False:  False
# False == False: True
# True and True:  True
# True or False: True

# %% [markdown]
# # Comparison Other Method

# %%
print(" 1 is 1 ", 1 is 1)
print("2 is 1", 2 is 1)
# Out:
#  1 is 1  True
# 2 is 1 False

# %%
print("A in Abhrahm", 'A' in 'Abhrahm')
# Out:
# A in Abhrahm True

# %%
print("B in Borh", 'B' in "Borh")
# Out:
# B in Borh True

# %%
print("Coding in Coding is good", 'Coding' in '''Coding is good''')
# Out:
# Coding in Coding is good True

# %%
print('a in an', "a" in "an")
# Out:
# a in an True

# %%
print("4 is 2**2", 4 is 2**2)
# Out:
# 4 is 2**2 True

# %% [markdown]
# # Logical Operators

# %%
print(3>2 and 4>5) #false
print(3>2 and 4<5) #true
print(3<2 and 4<5) #false
print(3>2 or 4>5) #true
print(3>2 or 4<5) #true
print(3<2 or 4<5) #true
# Out:
# False
# True
# False
# True
# True
# True

# %%
print(not 3<2)
print(not True)
print(not False)
print(not not True)
print(not not False)
# Out:
# True
# False
# True
# True
# False
