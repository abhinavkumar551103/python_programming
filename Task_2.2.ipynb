# %% [markdown]
# # Type Casting

# %% [raw]
# # Type Casting Now we contvert into int from different data types except text, and complex, Because Python does not support it.

# %%
int(2.3) # from float to int
# Out:
# 2

# %%
print(int(True)) # # from boolean to int
print(int(False))
# Out:
# 1
# 0

# %%
int('10') # from string but number into int
# Out:
# 10

# %%
int("ten") # string to int but text, and complex number into int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int("ten") # string to int but text, and complex number into int
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [raw]
# # Type conversion into float

# %%
float(10)
# Out:
# 10.0

# %%
print(float(True))
print(float(False))
# Out:
# 1.0
# 0.0

# %%
float('20')
# Out:
# 20.0

# %% [raw]
# # Convert into complex from differnt data type

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10, 20)
# Out:
# (10+20j)

# %%
complex(10, 0.3)
# Out:
# (10+0.3j)

# %%
complex(3.14)
# Out:
# (3.14+0j)

# %%
complex(True, False)
# Out:
# (1+0j)

# %%
complex(0 ,True)
# Out:
# 1j

# %%
complex('10')
# If only one argument is provided, it can be a string representing a valid number.
# However, if two arguments are provided (real, imag), neither argument can be a string.
# Both arguments must be numeric types (int or float).
# Out:
# (10+0j)

# %%
str(10)
# Out:
# '10'

# %%
str(3.14)
# Out:
# '3.14'

# %%
print(str(True))
print(str(False)) # But in string formate
# Out:
# 'False'

# %%
str(10+20j)
# Out:
# '(10+20j)'

# %%
str(10+20) # solve as a int but gives in string formate.
# Out:
# '30'

# %% [markdown]
# # Operator
# > Arithmetic opeator (+, -,  /,  *,  **,  //,  %)

# %%
x1 , x2 = 10, 5

# %%
x1 + x2
# Out:
# 15

# %%
x1 - x2
# Out:
# 5

# %%
x1 / x2
# Out:
# 2.0

# %%
x1 // x2
# Out:
# 2

# %%
x1 % x2
# Out:
# 0

# %%
x1 ** x2
# Out:
# 100000

# %% [markdown]
# # Assignment Operator

# %%
print(x1)
x1 += 2
print(x1)
# Out:
# 10
# 12

# %%
x = 2

# %%
x += 6

# %%
print(x)
# Out:
# 8

# %%
x -= 4

# %%
print(x)
# Out:
# 4

# %%
x *= 3

# %%
print(x)
# Out:
# 12

# %%
x /= 10
print(x)
# Out:
# 1.2

# %%
x //= 10

# %% [markdown]
# # Unary Operator

# %%
n = 7 
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
o = +(n)
o
# Out:
# 7

# %%
Neg = not(n)
Neg
# Out:
# False

# %% [markdown]
# # Relational operator

# %%
r1 = 5
r2 = 6

# %%
r1 > r2
# Out:
# False

# %%
r1 < r2
# Out:
# True

# %%
r1 == r2
# Out:
# False

# %%
r1 != r2
# Out:
# True

# %%
r1
# Out:
# 5

# %%
r2
# Out:
# 6

# %%
r3 = 6

# %%
r2 == r3
# Out:
# True

# %%
r3 >= r3
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
a , b = 5, 6

# %%
a < 8 and b < 9
# Out:
# True

# %%
a>2 or b<9
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %%
b>10 or a<10
# Out:
# True

# %%
p = False

# %%
not p
# Out:
# True
