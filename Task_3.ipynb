# %%
txt = "    abc def ghi    "
# basically strip() remove the unwanted spaces from string 
print(txt.lstrip()) #remove spaces from left side 
print(txt.rstrip()) #remove spaces from right side
print(txt.strip()) # remove spaces from both sides
# Out:
# abc def ghi
#     abc def ghi
# abc def ghi

# %%
mystr = "My favourite serial is \"Game of Thrones\""
print(mystr)
# Out:
# My favourite serial is "Game of Thrones"

# %%
list1 = []
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60]
list3 = [10.77,30.66,60.89]
list4 = ['One','two','three']
list5 = ['Asif', 25, [50,100],[150, 200]]
list6 = [100, 'Asif', 17.659]
list7 = ['Asif', 25, [50,100], [150, 90], {'John','David'}]
len(list6)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:dce612b4-7ca0-4333-90bd-f78c94b254ea.png)

# %% [markdown]
# # INDEXING IN LIST

# %%
list2[0]
# Out:
# 10

# %%
list4[0][1]
# Out:
# 'n'

# %%
list4[-1]
# Out:
# 'three'

# %%
print(list5[-1])
print(list5[-1][0]) # nested list element
# Out:
# [150, 200]
# 150

# %%
mylist = ['One','Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten']
mylist
# Out:
# ['One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten']

# %%
mylist[0:3]
# Out:
# ['One', 'Two', 'Three']

# %%
mylist[2:5]
# Out:
# ['Three', 'Four', 'Five']

# %%
print(mylist[:3])
print(mylist[:2])
# Out:
# ['One', 'Two', 'Three']
# ['One', 'Two']

# %%
mylist[-3:]
# Out:
# ['Eight', 'Nine', 'Ten']

# %%
mylist[-2:]
# Out:
# ['Nine', 'Ten']

# %%
mylist[-1]
# Out:
# 'Ten'

# %%
mylist[:]
# Out:
# ['One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten']

# %% [markdown]
# # OPERATIONS IN LIST

# %%
mylist.append('eleven') # basically its add the item in list at the end of the list

# %%
mylist.insert(3,3) # Basically we add list item on a particular index such as 0,1,2,...
mylist
# Out:
# ['One',
#  'Two',
#  'Three',
#  3,
#  'Four',
#  'Five',
#  'Six',
#  'Seven',
#  'Eight',
#  'Nine',
#  'Ten',
#  'eleven']

# %%
mylist.insert(1,'ONE')
mylist
# Out:
# ['One',
#  'ONE',
#  'Two',
#  'Three',
#  3,
#  'Four',
#  'Five',
#  'Six',
#  'Seven',
#  'Eight',
#  'Nine',
#  'Ten',
#  'eleven']

# %%
mylist.remove("ONE") # remove item from the list

# %%
mylist
# Out:
# ['One',
#  'Two',
#  'Three',
#  3,
#  'Four',
#  'Five',
#  'Six',
#  'Seven',
#  'Eight',
#  'Nine',
#  'Ten',
#  'eleven']

# %%
mylist.pop() # its remove the last item from the list or also work if need to remove a particular item from a index
# Out:
# 'Ten'

# %%
mylist.pop(4)
# Out:
# 'Nine'

# %%
mylist
# Out:
# ['One', 'Two', 3, 'Five']

# %%
del mylist[2]
mylist
# Out:
# ['One', 'Two', 'Five']

# %%
mylist[0] = "APPLE"  # changes the value of mylist items
mylist[1] = "BANANA"
mylist[2] = "CUSTARD APPLE"
mylist
# Out:
# ['APPLE', 'BANANA', 'CUSTARD APPLE']

# %%
mylist.clear() # remove all the elements from the list
mylist
# Out:
# []

# %%
del mylist # delete the list

# %%
mylist = ['one','Two','Three','Four','Five','Six','seven','Eight','Nine','Ten']

# %%
mylist2 = mylist.copy()

# %%
mylist2
# Out:
# ['one', 'Two', 'Three', 'Four', 'Five', 'Six', 'seven', 'Eight', 'Nine', 'Ten']

# %%
id(mylist), id(mylist2)
# Out:
# (1958112739840, 1958112745280)

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[0] = 1

# %%
mylist
# Out:
# [1, 'Two', 'Three', 'Four', 'Five', 'Six', 'seven', 'Eight', 'Nine', 'Ten']

# %%
mylist2
# Out:
# ['one', 'Two', 'Three', 'Four', 'Five', 'Six', 'seven', 'Eight', 'Nine', 'Ten']

# %% [raw]
# # Joining List

# %%
list3 = ['one','two','Three','Four','Five']
list4 = ['Six','Seven','Eight','Nine','Ten']

# %%
list_Merge = list3 + list4

# %%
list_Merge
# Out:
# ['one', 'two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten']

# %%
list3.extend(list4)
list3 # extend the list4 inside list3
# Out:
# ['one', 'two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten']

# %% [markdown]
# # List Memebership

# %%
list3
# Out:
# ['one', 'two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten']

# %%
'one' in list3
# Out:
# True

# %%
'Ten' in list3
# Out:
# True

# %%
if 'Three' in list3:
    print("The element is present in the list")
else:
    print("Element not present in the list")
# Out:
# The element is present in the list

# %%
if 'Eleven' in list3:
    print("The item is present in the list")
else: 
    print("The item is not present in the list")
# Out:
# The item is not present in the list

# %%
list3
# Out:
# ['one', 'two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten']

# %%
list3.reverse()
print(list3)
# Out:
# ['Ten', 'Nine', 'Eight', 'Seven', 'Six', 'Five', 'Four', 'Three', 'two', 'one']

# %%
list3[::-1]
list3
# Out:
# ['Ten', 'Nine', 'Eight', 'Seven', 'Six', 'Five', 'Four', 'Three', 'two', 'one']

# %%
mylist5 = [9,10,18,35,5,3,60,99,50,57,6,7]
mylist5
# Out:
# [9, 10, 18, 35, 5, 3, 60, 99, 50, 57, 6, 7]

# %%
mylist5.sort() #sort the list in ascending order
mylist5
# Out:
# [3, 5, 6, 7, 9, 10, 18, 35, 50, 57, 60, 99]

# %%
mylist5.sort(reverse=True)
mylist5  # sort list in decending order
# Out:
# [99, 60, 57, 50, 35, 18, 10, 9, 7, 6, 5, 3]

# %%
mylist_By_Sort = mylist5.sort()
print(mylist_By_Sort)
# Out:
# None

# %%
mylist6 = [90,10,75,57,42,9,5,21,38,28,82,83]
mylist_By_Sorted = sorted(mylist6) # Returns a new sorted list and doesn't change original list
print(mylist_By_Sorted) # Its also works on sets, tuples, dictionary, etc.
# Out:
# [5, 9, 10, 21, 28, 38, 42, 57, 75, 82, 83, 90]

# %% [markdown]
# # Loop in List

# %%
mylist_Fruits = ['Apple','Banana','Watermelon','Pine','Grapes']
mylist_Fruits
# Out:
# ['Apple', 'Banana', 'Watermelon', 'Pine', 'Grapes']

# %%
for i in mylist_Fruits:
        print(i)
# Out:
# Apple
# Banana
# Watermelon
# Pine
# Grapes

# %%
mylist_Fruits.append('Melon')

# %%
mylist_Fruits
# Out:
# ['Apple', 'Banana', 'Watermelon', 'Pine', 'Grapes', 'Melon']

# %%
for i in enumerate(mylist_Fruits):
    print(i) # It print items with there indexes
# Out:
# (0, 'Apple')
# (1, 'Banana')
# (2, 'Watermelon')
# (3, 'Pine')
# (4, 'Grapes')
# (5, 'Melon')

# %% [markdown]
# # COUNT

# %%
mylist8 = ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three'] 
mylist8
# Out:
# ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
mylist8.count('one')
# Out:
# 3

# %%
mylist8.count('two')
# Out:
# 2

# %%
mylist8.count('three')
# Out:
# 2

# %%
mylist8.count('four')
# Out:
# 1

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # its return falue if any value in list is false these values are consider as false in python
#  0,False,None,'', (empty string)[],{},set() if its contains in list its give false output.
# Out:
# False

# %%
L2 = [1,23,54,8,56,6,78,87]

# %%
all(L2) # the list holds only True values
# Out:
# True

# %%
L2.append(False)
L2
# Out:
# [1, 23, 54, 8, 56, 6, 78, 87, False]

# %%
all(L2) # Now its hold 0,False or any other false value so its shows false
# Out:
# False

# %%
L2.remove(False)

# %%
all(L2) # now false value is removed from list its again become truely value list
# Out:
# True

# %%
print(any([False, False, True])) # its vcheck if any one value is true then its give true and if all value are false then only its shows false.
# Out:
# True

# %% [raw]
# Basically all() and any() functions are perform logical operation its iterate the list,tuple,string,set,dictionary and perform, AND and OR operations for to checks all value are true or false in the data structure.
# Basically the any() refers to perform OR operation and all() refers to perform AND opertion.
